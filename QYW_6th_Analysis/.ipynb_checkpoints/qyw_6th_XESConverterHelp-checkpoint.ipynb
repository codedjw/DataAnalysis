# %%
import pandas as pd, numpy as np, matplotlib.pylab as plt
import MySQLdb

# %%
# Open database connection
conn = MySQLdb.connect(host='localhost',user='root',passwd='',db='qyw', charset='utf8')

# %%
user_visits = pd.read_sql('''
    SELECT * FROM qyw_4th_visit_done WHERE USER_ID IN (SELECT DISTINCT USER_ID FROM qyw.qyw_4th_visit_done WHERE VISIT_MEAN LIKE \'%预约%\');
    ''', con=conn)
user_visits.insert(0, 'CASE_ID','')

# %%
# 执行6min左右
import datetime
unique_users = user_visits['USER_ID'].unique()
for user_id in unique_users:
    # 一定要选择mergesort，这样才是稳定的（VISIT_TIME相同的行的index保证原有顺序）
    single_user_visits = user_visits[user_visits['USER_ID'] == user_id].sort_values(by=['VISIT_TIME'],ascending=[True],kind='mergesort')
    # 一定要更新index，否则index+1不对（因为sort_values有可能调换各行的顺序）
    single_user_visits.index = range(0,len(single_user_visits.index))
    size = len(single_user_visits.index)
    start = single_user_visits.index[0]
    date = None
    cid = 0
    for index, row in single_user_visits.iterrows():
        start_operate_time = row['VISIT_TIME']
        cur_date = start_operate_time.strftime('%Y-%m-%d')
        if not date:
            date = cur_date
        end_operate_time = start_operate_time
        next_date = cur_date
        if index < start+size-1:
            end_operate_time = single_user_visits.loc[index+1, 'VISIT_TIME']
            next_date = end_operate_time.strftime('%Y-%m-%d')
        interval = end_operate_time - start_operate_time
        interval_secs = interval.total_seconds()
        case_id = str(row['USER_ID'])+'@'+date+'_'+str(cid)
        single_user_visits.ix[index, 'CASE_ID'] = case_id
        if interval_secs > 5*60:
            if date != next_date:
                cid = 0
                date = next_date
            else:
                cid += 1
    single_user_visits.to_sql('qyw_4th_event', conn, flavor='mysql', if_exists='append', index=False)

# %%
user_visits
# Out:
#        CASE_ID   USER_ID          VISIT_TIME       VISIT_MEAN
# 0                   7885 2016-03-15 14:13:47          查询选中就诊者
# 1                   7885 2016-03-15 14:13:47      C端主页的预约挂号入口
# 2                   7885 2016-03-15 14:14:25           获取医生列表
# 3                   7885 2016-03-15 14:14:38           获取医生列表
# 4                   7885 2016-03-15 14:14:42           获取医生列表
# 5                   7885 2016-03-15 14:14:49           获取医生列表
# 6                   7885 2016-03-15 14:14:55           获取医生列表
# 7                   7885 2016-03-15 14:15:01           获取医生列表
# 8                   7885 2016-03-15 14:15:19           获取医生列表
# 9                   7885 2016-03-15 14:15:27           获取医生列表
# 10                  7885 2016-03-15 14:16:30       统计点击搜索模块次数
# 11                  7885 2016-03-15 16:32:42        绑定百度推送的账号
# 12                  7885 2016-03-15 16:32:42        检测白名单升级请求
# 13                  7885 2016-03-15 16:32:42          查询选中就诊者
# 14                  7885 2016-03-15 16:32:42     获取指定的某一个医院参数
# 15                  7885 2016-03-15 16:32:48          搜索和定位城市
# 16                  7885 2016-03-15 16:32:52       统计点击搜索模块次数
# 17                 13052 2016-03-09 23:01:13          查询选中就诊者
# 18                 13052 2016-03-09 23:01:17      C端主页的预约挂号入口
# 19                 13052 2016-03-09 23:01:24           我的排队科室
# 20                 13052 2016-03-09 23:02:00          待缴费记录查询
# 21                 13052 2016-03-09 23:02:04          待缴费记录查询
# 22                 13052 2016-03-09 23:03:19             查询省份
# 23                 13052 2016-03-09 23:03:19             查询城市
# 24                 13052 2016-03-10 09:05:09        检测白名单升级请求
# 25                 13052 2016-03-10 09:05:09        绑定百度推送的账号
# 26                 13052 2016-03-10 09:05:09          查询选中就诊者
# 27                 13052 2016-03-10 09:05:09             查询省份
# 28                 13052 2016-03-10 09:05:09             查询城市
# 29                 13052 2016-03-10 09:05:09     获取指定的某一个医院参数
# ...        ...       ...                 ...              ...
# 276606          10570566 2016-03-15 18:44:27             查询城市
# 276607          10570566 2016-03-15 18:45:24             查询省份
# 276608          10570566 2016-03-15 18:45:24             查询城市
# 276609          10570566 2016-03-15 18:45:30         获取预约挂号详情
# 276610          10570566 2016-03-15 18:45:30     获取指定的某一个医院参数
# 276611          10570566 2016-03-15 18:45:35          查询选中就诊者
# 276612          10570566 2016-03-15 18:46:06             查询省份
# 276613          10570566 2016-03-15 18:46:07             查询城市
# 276614          10570566 2016-03-15 18:46:23          查询选中就诊者
# 276615          10570566 2016-03-15 18:46:26      点击进入就诊卡管理界面
# 276616          10570566 2016-03-15 18:46:28          查询选中就诊者
# 276617          10570566 2016-03-15 18:46:36     获取指定的某一个医院参数
# 276618          10570566 2016-03-15 18:46:36  查询默认就诊者绑定的就诊卡信息
# 276619          10570566 2016-03-15 18:46:39          查询选中就诊者
# 276620          10570566 2016-03-15 18:46:41     获取指定的某一个医院参数
# 276621          10570566 2016-03-15 18:46:44          查询选中就诊者
# 276622          10570566 2016-03-15 18:46:52           查询系统消息
# 276623          10570566 2016-03-15 18:46:55           查询系统消息
# 276624          10570566 2016-03-15 18:46:55          查询选中就诊者
# 276625          10570566 2016-03-15 18:47:19          查询选中就诊者
# 276626          10570566 2016-03-15 18:47:22           查询系统消息
# 276627          10570566 2016-03-15 18:47:25           查询系统消息
# 276628          10570566 2016-03-15 18:47:29          查询选中就诊者
# 276629          10570725 2016-03-15 19:41:36        绑定百度推送的账号
# 276630          10570725 2016-03-15 19:41:36          查询选中就诊者
# 276631          10570725 2016-03-15 19:41:36        检测白名单升级请求
# 276632          10570725 2016-03-15 19:42:15             查询医院
# 276633          10570725 2016-03-15 19:42:19          查询选中就诊者
# 276634          10570725 2016-03-15 19:42:20      C端主页的预约挂号入口
# 276635          10570725 2016-03-15 19:42:37           获取医生列表
#
# [276636 rows x 4 columns]
